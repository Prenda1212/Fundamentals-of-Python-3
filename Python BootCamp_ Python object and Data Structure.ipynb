# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
from IPython.display import display, Image
display(Image(filename='Name of dtype.PNG'))

# %% [markdown]
# ## Python numbers

# %% [markdown]
# **Operator	Description	Example**
#
# ** + Addition	Adds values on either side of the operator.	a + b = 30
#
# ** - Subtraction	Subtracts right hand operand from left hand operand.	a – b = -10
#
# ** * Multiplication	Multiplies values on either side of the operator	a * b = 200
#
# ** / Division	Divides left hand operand by right hand operand	b / a = 2
#
# ** % Modulus	Divides left hand operand by right hand operand and returns remainder	b % a = 0
#
# ** ** Exponent	Performs exponential (power) calculation on operators	a**b =10 to the power 20
#
#
# ** //	Floor Division - The division of operands where the result is the quotient in which the digits after the decimal point are removed. But if one of the operands is negative, the result is floored, i.e., rounded away from zero (towards negative infinity) −	9//2 = 4 and 9.0//2.0 = 4.0, -11//3 = -4, -11.0//3 = -4.0
#
# url = 'https://www.tutorialspoint.com/python/python_basic_operators.htm'

# %%
# Python: Dynamic Datatype
# other lanuage: statistically datatype

# %% [markdown]
# ## python Assignment operators
# $\rightarrow$ =	Assigns values from right side operands to left side operand	c = a + b assigns value of a + b into c
#
# $\rightarrow$ += Add AND	It adds right operand to the left operand and assign the result to left operand	c += a is equivalent to c = c + a
#
# $\rightarrow$ -= Subtract AND	It subtracts right operand from the left operand and assign the result to left operand	c -= a is equivalent to c = c - a
#
# $\rightarrow$ *= Multiply AND	It multiplies right operand with the left operand and assign the result to left operand	c *= a is equivalent to c = c * a
#
# $\rightarrow$ /= Divide AND	It divides left operand with the right operand and assign the result to left operand	c /= a is equivalent to c = c / ac /= a is equivalent to c = c / a
#
# $\rightarrow$ %= Modulus AND	It takes modulus using two operands and assign the result to left operand	c %= a is equivalent to c = c % a
#
# $\rightarrow$ ***= Exponent AND	Performs exponential (power) calculation on operators and assign value to the left operand	c **= a is equivalent to c = c ** a
#
# $\rightarrow$ //= Floor Division	It performs floor division on operators and assign value to the left operand	c //= a is equivalent to c = c // a

# %%
t= 100
t_r=0.1
my_taxes = t*t_r
my_taxes
# Out:
# 10.0

# %%
#Creating conditions
x = 0
while x<5:
    print(f'The current value of x is {x}')
# you will have the output for unimited times
    x=x+1
# Out:
# The current value of x is 0
# The current value of x is 1
# The current value of x is 2
# The current value of x is 3
# The current value of x is 4

# %% [markdown]
# ## Introduction of String
#
# String Index
#
# String:  h  e  l  l  o
#
# index :  0  1  2  3  4
#
# R_index: 0 -4 -3 -2 -1
#
#
# next line: \n
#
# space: \t
#
# length of string: len()

# %% [markdown]
# **Square Bracket [ ]**

# %%
sr = 'hello'
sr[-1]
# Out:
# 'o'

# %%
sr[4]
# Out:
# 'o'

# %% [markdown]
# **Slicing [ ]**
#
# Syntax:
#     [start:stop:step]

# %%
st = 'abcdefghijk'

# %%
# grab every after 3
st[2:]
# Out:
# 'cdefghijk'

# %%
# grab every letter before d
# go up to d but not including 'd'
st[:3]
# Out:
# 'abc'

# %%
#only grab 'def'
st[3:6]
# Out:
# 'def'

# %%
# Step Size
#jump the step size of 2
st[: :2]
# Out:
# 'acegik'

# %%
#Reverse the string
st[: :-1]
# Out:
# 'kjihgfedcba'

# %% [markdown]
# ## String Properties

# %% [markdown]
# **Immutability**
#
# Strings are not mutable! (meaning you can't use indexing to change individual elements of a string)

# %%
name = "Sam"
# to replace 'S' to 'P'
last=name[1:]
'P' + last
# Out:
# 'Pam'

# %%
x="it's"
x = x + ' great to meet you'
x
# Out:
# "it's great to meet you"

# %% [markdown]
# If you are concate string with number,
# Then it will be give you a error

# %%
x.upper()
# Out:
# "IT'S GREAT TO MEET YOU"

# %%
x.split()
# Out:
# ["it's", 'great', 'to', 'meet', 'you']

# %%
x.split('e')
# Out:
# ["it's gr", 'at to m', '', 't you']

# %% [markdown]
# ## Printing Formatting
# .fortmat()
#
# f-strings

# %% [markdown]
# **.fortmat( )**

# %%
x = 'printing format'
print('This is a string {}'.format(x))
# Out:
# This is a string printing format

# %%
print('This is a string {} {}'.format('priting','string'))
# Out:
# This is a string priting string

# %%
y = ',great'
z =', covient'

print('This is a string {} {} {}'.format(x,y,z))
# Out:
# This is a string printing format ,great , covient

# %% [markdown]
# **Float Formating**
#
# float formatting "{value:width.precesion f}"

# %%
#
r = 100/177
r
print ("the result was {r:0.3f}".format(r=r))
# Out:
# the result was 0.565

# %% [markdown]
# **String showing method**

# %%
name = 'ok'
print (f'this is {name}')
# Out:
# this is ok

# %%
name = 'Dora'
age = 45
print (f'{name} is {age}')
# Out:
# Dora is 45

# %% [markdown]
# Resources on printing String and Num:
#     https://github.com/Pierian-Data/Complete-Python-3-Bootcamp/blob/master/00-Python%20Object%20and%20Data%20Structure%20Basics/03-Print%20Formatting%20with%20Strings.ipynb

# %% [markdown]
# ## Lists in Python

# %%
m = [1,2,3]

# %%
m =['one','two','three']
m_2 = ['four','five']

# %%
m[1]
# Out:
# 'two'

# %%
new_m = m + m_2
new_m
# Out:
# ['one', 'two', 'three', 'four', 'five']

# %%
new_m[2] = 'New three'

# %%
new_m
# Out:
# ['one', 'two', 'New three', 'four', 'five']

# %% [markdown]
# **. append()**

# %%
#Using append, to add item to the rest of the list
new_m.append('six')
new_m
# Out:
# ['one', 'two', 'New three', 'four', 'five', 'six', 'six']

# %% [markdown]
# **.pop()**

# %%
#Removing items from the last item from the list which just append
new_m.pop()
new_m
# Out:
# ['one', 'two', 'New three', 'four', 'five']

# %%
# if you'd like to remove 'new_three'
new_m.pop(-3)
# Out:
# 'New three'

# %%
new_m
# Out:
# ['one', 'two', 'four', 'five']

# %% [markdown]
# **.sort ( )**
#
# in-place actions

# %%
new_l = ['a','c','i','p','b','f']

# %%
new_l.sort()

# %%
#sorting in alphebetical order
new_l
# Out:
# ['a', 'b', 'c', 'f', 'i', 'p']

# %%
new_n = [1,2,9,3,4,45,12,10]

new_n.sort()

# %%
new_n
# Out:
# [1, 2, 3, 4, 9, 10, 12, 45]

# %%
#You cannot do new_l0=new_l.sort()
#only following could help
new_l.sort()
my_sort_l=new_l

# %%
my_sort_l
# Out:
# ['a', 'b', 'c', 'f', 'i', 'p']

# %%
#Reverse command
my_sort_l.reverse()
my_sort_l
# Out:
# ['p', 'i', 'f', 'c', 'b', 'a']

# %%
new_n.reverse()
new_n
# Out:
# [45, 12, 10, 9, 4, 3, 2, 1]

# %% [markdown]
# ## Dictionaries
#
# {'key1':'value1','key2':'value2'}
#
# Dictionary: un-ordered and cannot be sorted
#
# Lists: ordered Sequence can be indexed or sliced

# %%
dict ={'key1':'value1','key2':'value2'}

# %%
dict['key1']
# Out:
# 'value1'

# %%
dict ={'key1':['a','b','c'],'key2':[1,2,3],'key3':{'key_sub3':'value3'}}

# %%
dict['key3']['key_sub3']
# Out:
# 'value3'

# %%
#To have a upper case of value in 'key1'
dict['key1'][0].upper()
# Out:
# 'A'

# %%
dict_l = dict['key1']

# %%
d = {'key1':100,'key2':200,'key3':300}

# %%
#Adding a new key in dictionary
d['key4']=400

# %%
d
# Out:
# {'key1': 100, 'key2': 200, 'key3': 300, 'key4': 400}

# %%
#assigning new value to specific key
d['key1']='new value'

# %%
d
# Out:
# {'key1': 'new value', 'key2': 200, 'key3': 300, 'key4': 400}

# %%
d.values()
# Out:
# dict_values(['new value', 200, 300, 400])

# %%
d.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3', 'key4'])

# %%
d.items()
#This is a tuple set
# Out:
# dict_items([('key1', 'new value'), ('key2', 200), ('key3', 300), ('key4', 400)])

# %% [markdown]
# Dictionaries are mappings and do not retain order! If you do want the capabilities of a dictionary but you would like ordering as well, check out the ordereddict object lecture later on in the course!

# %% [markdown]
# ## Tuples
# immutability: once the elment has been assigned into tuple, then it could not be reassigned to other lists

# %%
t=(1,2,3)
z=[1,2,3]

# %%
type(t)
# Out:
# tuple

# %%
type(z)
# Out:
# list

# %% [markdown]
# **Indexing method**

# %%
t=('a','b','c','c','d')
t.count('c')
# Out:
# 2

# %%
#The index location where'c' first appears in your tupple
t.index('d')
# Out:
# 4

# %% [markdown]
# **immutability**:
# it does not allow for letter re-assignments

# %%
z[0]='ok'
z
# Out:
# ['ok', 2, 3]

# %%
t[0]='ok'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-130-a742f8344416> in <module>
# ----> 1 q[0]='ok'
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# It's the properties of Tuple, as tuple is **immutability**

# %% [markdown]
# ## Sets
#
# it could only add unique value, if the value is already in the set, it won't add the repeated value twice.

# %%
m = set()
m.add(1)
m
# Out:
# {1}

# %%
m.add(2)
m
# Out:
# {1, 2}

# %%
mylist = [1,1,1,3,3,3,6,6,6,7,7,7,'ok','ok','dg']

# %%
set(mylist)
# Out:
# {1, 3, 6, 7, 'dg', 'ok'}

# %% [markdown]
# ## Booleans
#
# Allow you to return if you can grab True or Flase statements

# %%
type(False)
# Out:
# bool

# %%
'a' in 'apple'
# Out:
# True

# %% [markdown]
# ## Python I/O Files

# %% [markdown]
# Python uses file objects to interact with external files on your computer. These file objects can be any sort of file you have on your computer, whether it be an audio file, a text file, emails, Excel documents, etc. Note: You will probably need to install certain libraries or modules to interact with those various file types, but they are easily available. (We will cover downloading modules later on in the course).
#
# url = 'https://github.com/Pierian-Data/Complete-Python-3-Bootcamp/blob/master/00-Python%20Object%20and%20Data%20Structure%20Basics/08-Files.ipynb'

# %% [markdown]
# **Writing in the txt file**

# %%
# %%writefile test.txt
# Hello, this is a quick test file.
# Out:
# Overwriting test.txt

# %%
pwd
# Out:
# '/Users/Brenda-Liu-Life'

# %%
myfile = open('test.txt')
myfile.read()
# Out:
# 'Hello, this is a quick test file.\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello, this is a quick test file.\n']

# %%
nd_file=open('/Users/Brenda-Liu-Life/McGill/2019 self learning/Python/Fundemental Class/mytextarray.txt')

# %%
nd_file.seek(0)
nd_file.read()
# Out:
# '1.000000000000000000e+00,2.000000000000000000e+00,3.000000000000000000e+00\n4.000000000000000000e+00,5.000000000000000000e+00,6.000000000000000000e+00\n'

# %%
nd_file.close()

# %%
myfile.close()

# %% [markdown]
# **Avoiding file usage in python and file editing at same time**

# %%
with open('test.txt') as my_new_file:
    contents = my_new_file.read()

# %%
contents
# Out:
# 'Hello, this is a quick test file.\n'

# %%
#Using Shift + Tab
with open('test.txt',mode ='r') as myfile:
    contetns = myfile.read()

# %% [markdown]
# **Mode	Description**
#
# 'r'	This is the default mode. It Opens file for reading.
#
# 'w'	This Mode Opens file for writing.
# If file does not exist, it creates a new file.
# If file exists it truncates the file.
#
# 'x'	Creates a new file. If file already exists, the operation fails.
#
# 'a'	Open file in append mode.
# If file does not exist, it creates a new file.
#
# 't'	This is the default mode. It opens in text mode.
#
# 'b'	This opens in binary mode.
#
# '+'	This will open a file for reading and writing (updating)

# %%
# %%writefile test.txt
# one on first
# two on second
# three on third
# Out:
# Overwriting test.txt

# %%
with open ('test.txt',mode='a') as f:
    f.write('Four on forth')

# %%
#append
with open ('test.txt',mode='r') as f:
    print(f.read())
# Out:
# one on first
# two on second
# three on third
# Four on forth

# %% [markdown]
# ## Comparison Operators

# %% [markdown]
# For the following quiz questions, we will get a preview of comparison operators. In the table below, a=3 and b=4.
#
# <table class="table table-bordered">
# <tr>
# <th style="width:10%">Operator</th><th style="width:45%">Description</th><th>Example</th>
# </tr>
# <tr>
# <td>==</td>
# <td>If the values of two operands are equal, then the condition becomes true.</td>
# <td> (a == b) is not true.</td>
# </tr>
# <tr>
# <td>!=</td>
# <td>If values of two operands are not equal, then condition becomes true.</td>
# <td> (a != b) is true.</td>
# </tr>
# <tr>
# <td>&gt;</td>
# <td>If the value of left operand is greater than the value of right operand, then condition becomes true.</td>
# <td> (a &gt; b) is not true.</td>
# </tr>
# <tr>
# <td>&lt;</td>
# <td>If the value of left operand is less than the value of right operand, then condition becomes true.</td>
# <td> (a &lt; b) is true.</td>
# </tr>
# <tr>
# <td>&gt;=</td>
# <td>If the value of left operand is greater than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &gt;= b) is not true. </td>
# </tr>
# <tr>
# <td>&lt;=</td>
# <td>If the value of left operand is less than or equal to the value of right operand, then condition becomes true.</td>
# <td> (a &lt;= b) is true. </td>
# </tr>
# </table>

# %%
3 != 3
# Out:
# False

# %%
3 == 3
# Out:
# True

# %% [markdown]
# ## Logical Operators
# - and
# - or
# - not

# %%
'a' in 'apple' or 'c' in 'bus'
# Out:
# True

# %%
'a' in'apple' and 'c' in 'bus'
# Out:
# False

# %%
not('a' in'apple' and 'c' in 'bus')
# Out:
# True

# %%
not(345 <600)
# Out:
# False

# %% [markdown]
# ## Other Resources

# %% [markdown]
# Basic Practice:
#
# http://codingbat.com/python
#
# More Mathematical (and Harder) Practice:
#
# https://projecteuler.net/archives
#
# List of Practice Problems:
#
# http://www.codeabbey.com/index/task_list
#
# A SubReddit Devoted to Daily Practice Problems:
#
# https://www.reddit.com/r/dailyprogrammer
#
# A very tricky website with very few hints and touch problems (Not for beginners but still interesting)
#
# http://www.pythonchallenge.com/

# %% [markdown]
# ## End of Python Object and Data Structures
